# %% [markdown]
# #  Capstone Project Assigment The Battle of Neighborhoods

# %% [markdown]
# ### Import Library

# %%
import requests
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
from geopy.geocoders import Nominatim
import folium
import json
from IPython.display import Image 
from IPython.core.display import HTML

# %% [markdown]
# # FourSquare Api Credentaials

# %%
ClIENT_ID = 'G4G3BSMIJBOKSRFTLMKCCHCOYYAA5B4WMD1AHJPG0YN5RJ5P' # your Foursquare ID
ClIENT_SECRET = 'DSQT5Q4DQVFK04CDBSMY2ALHS5W50FZFVIYTQAZVLXWXKTCR' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: G4G3BSMIJBOKSRFTLMKCCHCOYYAA5B4WMD1AHJPG0YN5RJ5P
# Foursquare_Secret:DSQT5Q4DQVFK04CDBSMY2ALHS5W50FZFVIYTQAZVLXWXKTCR

# %%
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %% [markdown]
# # Create DataFerame Hotel

# %%
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=G4G3BSMIJBOKSRFTLMKCCHCOYYAA5B4WMD1AHJPG0YN5RJ5P&client_secret=DSQT5Q4DQVFK04CDBSMY2ALHS5W50FZFVIYTQAZVLXWXKTCR&ll=43.653963,-79.387207&v=20180604&query=Hotel&radius=500&limit=30'

# %%
results = requests.get(url).json()
venues = results['response']['venues']
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# <ipython-input-5-bc0f259b5133>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id                                            name  \
# 0  4ab2d511f964a5209b6c20e3                   Sheraton Centre Toronto Hotel
# 1  4b68aed1f964a520de862be3                  The Rex Hotel Jazz & Blues Bar
# 2  4f343a31e4b0230a3b337a90                                  VFM Test Hotel
# 3  5545d07e498e2facac03f666  Sheraton Centre Toronto Hotel - Grand Ballroom
# 4  4f53fb2ee4b036244bea152f                                 Stathcona Hotel
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1584887028    False
# 1  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...  v-1584887028    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1584887028    False
# 3  [{'id': '56aa371be4b08b9a8d5734cf', 'name': 'B...  v-1584887028    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1584887028    False
#
#         location.address location.crossStreet  location.lat  location.lng  \
# 0  123 Queen Street West          at York St.     43.650594    -79.384530
# 1         194 Queen St W  Queen & St. Patrick     43.650505    -79.388577
# 2         123 Test Drive      at somewhere St     43.658434    -79.387894
# 3  123 Queen Street West        at Bay Street     43.651200    -79.384520
# 4                    NaN                  NaN     43.654947    -79.386359
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...                432
# 1  [{'label': 'display', 'lat': 43.65050475544005...                400
# 2  [{'label': 'display', 'lat': 43.658434, 'lng':...                500
# 3  [{'label': 'display', 'lat': 43.65119976208405...                376
# 4  [{'label': 'display', 'lat': 43.654947, 'lng':...                129
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5H 2M9          CA       Toronto             ON
# 1             M5V 1Z1          CA       Toronto             ON
# 2             M2M 2M2          CA       Toronto             ON
# 3                 NaN          CA       Toronto             ON
# 4                 NaN          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [123 Queen Street West (at York St.), Toronto ...
# 1           Canada  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2           Canada  [123 Test Drive (at somewhere St), Toronto ON ...
# 3           Canada  [123 Queen Street West (at Bay Street), Toront...
# 4           Canada                               [Toronto ON, Canada]
#
#   venuePage.id location.neighborhood
# 0          NaN                   NaN
# 1     62225795                   NaN
# 2          NaN                   NaN
# 3          NaN    Financial District
# 4          NaN                   NaN

# %%
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]
clean_dataframe.head()
# Out:
#                                              name categories  \
# 0                   Sheraton Centre Toronto Hotel      Hotel
# 1                  The Rex Hotel Jazz & Blues Bar  Jazz Club
# 2                                  VFM Test Hotel      Hotel
# 3  Sheraton Centre Toronto Hotel - Grand Ballroom   Ballroom
# 4                                 Stathcona Hotel      Hotel
#
#                  address          crossStreet        lat        lng  \
# 0  123 Queen Street West          at York St.  43.650594 -79.384530
# 1         194 Queen St W  Queen & St. Patrick  43.650505 -79.388577
# 2         123 Test Drive      at somewhere St  43.658434 -79.387894
# 3  123 Queen Street West        at Bay Street  43.651200 -79.384520
# 4                    NaN                  NaN  43.654947 -79.386359
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...       432    M5H 2M9  CA
# 1  [{'label': 'display', 'lat': 43.65050475544005...       400    M5V 1Z1  CA
# 2  [{'label': 'display', 'lat': 43.658434, 'lng':...       500    M2M 2M2  CA
# 3  [{'label': 'display', 'lat': 43.65119976208405...       376        NaN  CA
# 4  [{'label': 'display', 'lat': 43.654947, 'lng':...       129        NaN  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [123 Queen Street West (at York St.), Toronto ...
# 1  Toronto    ON  Canada  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  Toronto    ON  Canada  [123 Test Drive (at somewhere St), Toronto ON ...
# 3  Toronto    ON  Canada  [123 Queen Street West (at Bay Street), Toront...
# 4  Toronto    ON  Canada                               [Toronto ON, Canada]
#
#          neighborhood                        id
# 0                 NaN  4ab2d511f964a5209b6c20e3
# 1                 NaN  4b68aed1f964a520de862be3
# 2                 NaN  4f343a31e4b0230a3b337a90
# 3  Financial District  5545d07e498e2facac03f666
# 4                 NaN  4f53fb2ee4b036244bea152f

# %%
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2.head()
# Out:
#                                              name categories  \
# 0                   Sheraton Centre Toronto Hotel      Hotel
# 1                  The Rex Hotel Jazz & Blues Bar  Jazz Club
# 2                                  VFM Test Hotel      Hotel
# 3  Sheraton Centre Toronto Hotel - Grand Ballroom   Ballroom
# 4                                 Stathcona Hotel      Hotel
#
#                  address        lat        lng postalCode state
# 0  123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1         194 Queen St W  43.650505 -79.388577    M5V 1Z1    ON
# 2         123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 3  123 Queen Street West  43.651200 -79.384520        NaN    ON
# 4                    NaN  43.654947 -79.386359        NaN    ON

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3.head()
# Out:
#                              name categories                address  \
# 0   Sheraton Centre Toronto Hotel      Hotel  123 Queen Street West
# 1  The Rex Hotel Jazz & Blues Bar  Jazz Club         194 Queen St W
# 2                  VFM Test Hotel      Hotel         123 Test Drive
# 8            DoubleTree by Hilton      Hotel    108 Chestnut Street
# 9              Shangri-La Toronto      Hotel    188 University Ave.
#
#          lat        lng postalCode state
# 0  43.650594 -79.384530    M5H 2M9    ON
# 1  43.650505 -79.388577    M5V 1Z1    ON
# 2  43.658434 -79.387894    M2M 2M2    ON
# 8  43.654608 -79.385942    M5G 1R3    ON
# 9  43.649129 -79.386557    M5H 0A3    ON

# %%
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2                                 VFM Test Hotel        Hotel
# 8                           DoubleTree by Hilton        Hotel
# 9                             Shangri-La Toronto        Hotel
# 10                                        Hilton        Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 19                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 2          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 8     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 9     188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 10      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 19        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2                                 VFM Test Hotel        Hotel
# 8                           DoubleTree by Hilton        Hotel
# 9                             Shangri-La Toronto        Hotel
# 10                                        Hilton        Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 19                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 2          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 8     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 9     188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 10      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 19        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 19                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.650594 -79.384530    M5H 2M9    ON
# 19  43.651217 -79.383771    M5H 2M9    ON

# %% [markdown]
# # Create DataFrame PArk

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=G4G3BSMIJBOKSRFTLMKCCHCOYYAA5B4WMD1AHJPG0YN5RJ5P&client_secret=DSQT5Q4DQVFK04CDBSMY2ALHS5W50FZFVIYTQAZVLXWXKTCR&ll=43.653963,-79.387207&v=20180604&query=Park&radius=10000&limit=30'

# %%
presults = requests.get(url).json()
venues = presults['response']['venues']
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
# <ipython-input-13-6d026bc5e16c>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   park_dataframe = json_normalize(venues)
#                          id                              name  \
# 0  4b170e47f964a5208cc123e3       Queen's Park Subway Station
# 1  4b54deadf964a520a3d027e3                       Grange Park
# 2  4b9d206bf964a520e69136e3                      Queen's Park
# 3  4d3a1d23325ff04db2dd1845  Residences at College Park North
# 4  4bb79860cf2fc9b616779e02                       Berczy Park
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...  v-1584887051    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1584887051    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1584887051    False
# 3  [{'id': '4d954b06a243a5684965b473', 'name': 'R...  v-1584887051    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1584887051    False
#
#          location.address               location.crossStreet  location.lat  \
# 0      691 University Ave                      at College St     43.660006
# 1                     NaN                                NaN     43.652488
# 2         University Ave.                  at Wellesley Ave.     43.663946
# 3             763 Bay St.  btwn. College St. and Gerrard St.     43.659822
# 4  35 Wellington St. East                                NaN     43.648048
#
#    location.lng                            location.labeledLatLngs  \
# 0    -79.390272  [{'label': 'display', 'lat': 43.66000635700919...
# 1    -79.392053  [{'label': 'display', 'lat': 43.65248755299856...
# 2    -79.392180  [{'label': 'display', 'lat': 43.66394609897775...
# 3    -79.385159  [{'label': 'display', 'lat': 43.65982157793473...
# 4    -79.375172  [{'label': 'display', 'lat': 43.64804835388851...
#
#    location.distance location.postalCode location.cc location.city  \
# 0                716             M5G 2P1          CA       Toronto
# 1                423                 NaN          CA       Toronto
# 2               1181             M5R 2E8          CA       Toronto
# 3                672             M5G 2R3          CA       Toronto
# 4               1171                 NaN          CA       Toronto
#
#   location.state location.country  \
# 0             ON           Canada
# 1             ON           Canada
# 2             ON           Canada
# 3             ON           Canada
# 4             ON           Canada
#
#                            location.formattedAddress venuePage.id
# 0  [691 University Ave (at College St), Toronto O...          NaN
# 1  [btwn College, University, Queen & Spadina, To...          NaN
# 2  [University Ave. (at Wellesley Ave.), Toronto ...          NaN
# 3  [763 Bay St. (btwn. College St. and Gerrard St...          NaN
# 4       [35 Wellington St. East, Toronto ON, Canada]          NaN

# %%
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]
clean_park_dataframe.head()
# Out:
#                                name                                categories  \
# 0       Queen's Park Subway Station                             Metro Station
# 1                       Grange Park                                      Park
# 2                      Queen's Park                                      Park
# 3  Residences at College Park North  Residential Building (Apartment / Condo)
# 4                       Berczy Park                                      Park
#
#                   address                        crossStreet        lat  \
# 0      691 University Ave                      at College St  43.660006
# 1                     NaN                                NaN  43.652488
# 2         University Ave.                  at Wellesley Ave.  43.663946
# 3             763 Bay St.  btwn. College St. and Gerrard St.  43.659822
# 4  35 Wellington St. East                                NaN  43.648048
#
#          lng                                     labeledLatLngs  distance  \
# 0 -79.390272  [{'label': 'display', 'lat': 43.66000635700919...       716
# 1 -79.392053  [{'label': 'display', 'lat': 43.65248755299856...       423
# 2 -79.392180  [{'label': 'display', 'lat': 43.66394609897775...      1181
# 3 -79.385159  [{'label': 'display', 'lat': 43.65982157793473...       672
# 4 -79.375172  [{'label': 'display', 'lat': 43.64804835388851...      1171
#
#   postalCode  cc     city state country  \
# 0    M5G 2P1  CA  Toronto    ON  Canada
# 1        NaN  CA  Toronto    ON  Canada
# 2    M5R 2E8  CA  Toronto    ON  Canada
# 3    M5G 2R3  CA  Toronto    ON  Canada
# 4        NaN  CA  Toronto    ON  Canada
#
#                                     formattedAddress                        id
# 0  [691 University Ave (at College St), Toronto O...  4b170e47f964a5208cc123e3
# 1  [btwn College, University, Queen & Spadina, To...  4b54deadf964a520a3d027e3
# 2  [University Ave. (at Wellesley Ave.), Toronto ...  4b9d206bf964a520e69136e3
# 3  [763 Bay St. (btwn. College St. and Gerrard St...  4d3a1d23325ff04db2dd1845
# 4       [35 Wellington St. East, Toronto ON, Canada]  4bb79860cf2fc9b616779e02

# %%
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2.head()
# Out:
#                                name                                categories  \
# 0       Queen's Park Subway Station                             Metro Station
# 1                       Grange Park                                      Park
# 2                      Queen's Park                                      Park
# 3  Residences at College Park North  Residential Building (Apartment / Condo)
# 4                       Berczy Park                                      Park
#
#                   address        lat        lng postalCode state
# 0      691 University Ave  43.660006 -79.390272    M5G 2P1    ON
# 1                     NaN  43.652488 -79.392053        NaN    ON
# 2         University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 3             763 Bay St.  43.659822 -79.385159    M5G 2R3    ON
# 4  35 Wellington St. East  43.648048 -79.375172        NaN    ON

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3.head()
# Out:
#                                name                                categories  \
# 0       Queen's Park Subway Station                             Metro Station
# 2                      Queen's Park                                      Park
# 3  Residences at College Park North  Residential Building (Apartment / Condo)
# 6                     One Park Lane  Residential Building (Apartment / Condo)
# 7     Crunch Fitness - College Park                      Gym / Fitness Center
#
#               address        lat        lng postalCode state
# 0  691 University Ave  43.660006 -79.390272    M5G 2P1    ON
# 2     University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 3         763 Bay St.  43.659822 -79.385159    M5G 2R3    ON
# 6       280 Simcoe St  43.655442 -79.390056    M5T 2Y5    ON
# 7    382 Yonge Street  43.659263 -79.382632    M5G 1S8    ON

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park.head()
# Out:
#                       name categories                       address  \
# 2             Queen's Park       Park               University Ave.
# 10    Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 13      Canoe Landing Park       Park             50 Fort York Blvd
# 14     Riverdale Park West       Park               500 Gerrard St.
# 17  Trinity Bellwoods Park       Park            1053 Dundas St. W.
#
#           lat        lng postalCode state
# 2   43.663946 -79.392180    M5R 2E8    ON
# 10  43.653610 -79.402199    M5T 2N4    ON
# 13  43.638762 -79.397067    M5V 3Z1    ON
# 14  43.666048 -79.360941    M5A 2H3    ON
# 17  43.647072 -79.413756    M5H 2N2    ON

# %% [markdown]
# # Create DataFrame Restaurant

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=G4G3BSMIJBOKSRFTLMKCCHCOYYAA5B4WMD1AHJPG0YN5RJ5P&client_secret=DSQT5Q4DQVFK04CDBSMY2ALHS5W50FZFVIYTQAZVLXWXKTCR&ll=43.653963,-79.387207&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
Rresults = requests.get(url).json()
venues = Rresults['response']['venues']
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
# <ipython-input-19-9accf9f220c3>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   Restaurant_dataframe = json_normalize(venues)
#                          id                                name  \
# 0  4ad4c05ff964a52048f720e3     Hemispheres Restaurant & Bistro
# 1  4b223f5af964a520ba4424e3              Azure Restaurant & Bar
# 2  4ad4c060f964a5207ff720e3              Rol San Restaurant 龍笙棧
# 3  4ad4c05cf964a520dff520e3                      360 Restaurant
# 4  4b072e9df964a52009f922e3  Sky Dragon Chinese Restaurant 龍翔酒樓
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1584887053    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1584887053    False
# 2  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1584887053    False
# 3  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...  v-1584887053    False
# 4  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1584887053    False
#
#       location.address  location.lat  location.lng  \
# 0  110 Chestnut Street     43.654884    -79.385931
# 1       225 Front St W     43.644749    -79.385113
# 2     323 Spadina Ave.     43.654318    -79.398650
# 3       301 Front St W     43.642537    -79.387042
# 4     280 Spadina Ave.     43.652783    -79.398174
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...                145
# 1  [{'label': 'display', 'lat': 43.64474919591934...               1039
# 2  [{'label': 'display', 'lat': 43.65431754076345...                922
# 3  [{'label': 'display', 'lat': 43.64253731714456...               1271
# 4  [{'label': 'display', 'lat': 43.65278331265585...                892
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 1R3          CA       Toronto             ON
# 1             M5V 2X3          CA       Toronto             ON
# 2             M5T 2E9          CA       Toronto             ON
# 3             M5V 2T6          CA       Toronto             ON
# 4                 NaN          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1           Canada  [225 Front St W (in InterContinental Toronto C...
# 2           Canada  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 3           Canada  [301 Front St W (301 Front St. W), Toronto ON ...
# 4           Canada  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
#
#                  location.crossStreet   location.neighborhood venuePage.id
# 0                                 NaN                     NaN          NaN
# 1  in InterContinental Toronto Centre  Entertainment District    136175835
# 2                       at D'Arcy St.       Kensington Market          NaN
# 3                     301 Front St. W                     NaN          NaN
# 4                    at Dundas St. W.                     NaN          NaN

# %%
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]
clean_Restaurant_dataframe.head()
# Out:
#                                  name           categories  \
# 0     Hemispheres Restaurant & Bistro  American Restaurant
# 1              Azure Restaurant & Bar           Restaurant
# 2              Rol San Restaurant 龍笙棧   Dim Sum Restaurant
# 3                      360 Restaurant             Wine Bar
# 4  Sky Dragon Chinese Restaurant 龍翔酒樓   Dim Sum Restaurant
#
#                address        lat        lng  \
# 0  110 Chestnut Street  43.654884 -79.385931
# 1       225 Front St W  43.644749 -79.385113
# 2     323 Spadina Ave.  43.654318 -79.398650
# 3       301 Front St W  43.642537 -79.387042
# 4     280 Spadina Ave.  43.652783 -79.398174
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...       145    M5G 1R3  CA
# 1  [{'label': 'display', 'lat': 43.64474919591934...      1039    M5V 2X3  CA
# 2  [{'label': 'display', 'lat': 43.65431754076345...       922    M5T 2E9  CA
# 3  [{'label': 'display', 'lat': 43.64253731714456...      1271    M5V 2T6  CA
# 4  [{'label': 'display', 'lat': 43.65278331265585...       892        NaN  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  Toronto    ON  Canada  [225 Front St W (in InterContinental Toronto C...
# 2  Toronto    ON  Canada  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 3  Toronto    ON  Canada  [301 Front St W (301 Front St. W), Toronto ON ...
# 4  Toronto    ON  Canada  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
#
#                           crossStreet            neighborhood  \
# 0                                 NaN                     NaN
# 1  in InterContinental Toronto Centre  Entertainment District
# 2                       at D'Arcy St.       Kensington Market
# 3                     301 Front St. W                     NaN
# 4                    at Dundas St. W.                     NaN
#
#                          id
# 0  4ad4c05ff964a52048f720e3
# 1  4b223f5af964a520ba4424e3
# 2  4ad4c060f964a5207ff720e3
# 3  4ad4c05cf964a520dff520e3
# 4  4b072e9df964a52009f922e3

# %%
#delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2.head()
# Out:
#                                  name           categories  \
# 0     Hemispheres Restaurant & Bistro  American Restaurant
# 1              Azure Restaurant & Bar           Restaurant
# 2              Rol San Restaurant 龍笙棧   Dim Sum Restaurant
# 3                      360 Restaurant             Wine Bar
# 4  Sky Dragon Chinese Restaurant 龍翔酒樓   Dim Sum Restaurant
#
#                address        lat        lng postalCode state
# 0  110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1       225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 2     323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 3       301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 4     280 Spadina Ave.  43.652783 -79.398174        NaN    ON

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant.head()
# Out:
#                               name           categories              address  \
# 0  Hemispheres Restaurant & Bistro  American Restaurant  110 Chestnut Street
# 1           Azure Restaurant & Bar           Restaurant       225 Front St W
# 2           Rol San Restaurant 龍笙棧   Dim Sum Restaurant     323 Spadina Ave.
# 3                   360 Restaurant             Wine Bar       301 Front St W
# 5   Goldstone Noodle Restaurant 金石         Noodle House      266 Spadina Ave
#
#          lat        lng postalCode state
# 0  43.654884 -79.385931    M5G 1R3    ON
# 1  43.644749 -79.385113    M5V 2X3    ON
# 2  43.654318 -79.398650    M5T 2E9    ON
# 3  43.642537 -79.387042    M5V 2T6    ON
# 5  43.652278 -79.398039    M5T 2E4    ON

# %% [markdown]
# # Create DataFrame Cafeteria

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=G4G3BSMIJBOKSRFTLMKCCHCOYYAA5B4WMD1AHJPG0YN5RJ5P&client_secret=DSQT5Q4DQVFK04CDBSMY2ALHS5W50FZFVIYTQAZVLXWXKTCR&ll=43.653963,-79.387207&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
cresults = requests.get(url).json()
venues = cresults['response']['venues']
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
# <ipython-input-24-0fbedda48d2f>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   Cafeteria_dataframe = json_normalize(venues)
#                          id                           name  \
# 0  4f9165bde4b04fef0087e4e2                      Cafeteria
# 1  528e99a211d262edc3708a6f              Stay Cafeteria 慢走
# 2  53bd6dfe498e6c1d3bc9333e  Industrial Alliance Cafeteria
# 3  556f826b498e07f469e6bf1f                Dears Cafeteria
# 4  4ec2b68a8231a83de8c45191                 OCAD Cafeteria
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1584887055    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1584887055    False
# 2  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...  v-1584887055    False
# 3  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...  v-1584887055    False
# 4  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...  v-1584887055    False
#
#                             location.address  location.lat  location.lng  \
# 0  The Hospital for Sick Children (SickKids)     43.657209    -79.386063
# 1                            388 Spadina Ave     43.655454    -79.399163
# 2                                        NaN     43.655657    -79.389443
# 3                                        NaN     43.654179    -79.392555
# 4                             100 McCaul St.     43.652780    -79.391762
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...                372
# 1  [{'label': 'display', 'lat': 43.65545427446646...                977
# 2  [{'label': 'display', 'lat': 43.655657, 'lng':...                260
# 3  [{'label': 'display', 'lat': 43.65417861938476...                431
# 4  [{'label': 'display', 'lat': 43.65278016892648...                389
#
#   location.cc location.city location.state location.country  \
# 0          CA       Toronto             ON           Canada
# 1          CA       Toronto             ON           Canada
# 2          CA       Toronto             ON           Canada
# 3          CA           NaN            NaN           Canada
# 4          CA       Toronto             ON           Canada
#
#                            location.formattedAddress location.crossStreet  \
# 0  [The Hospital for Sick Children (SickKids), To...                  NaN
# 1  [388 Spadina Ave (at Nassau St), Toronto ON M5...         at Nassau St
# 2                               [Toronto ON, Canada]                  NaN
# 3                                           [Canada]                  NaN
# 4  [100 McCaul St. (Second Floor), Toronto ON, Ca...         Second Floor
#
#   location.postalCode
# 0                 NaN
# 1             M5T 2G5
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]
clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2  Industrial Alliance Cafeteria             Cafeteria
# 3                Dears Cafeteria          Dessert Shop
# 4                 OCAD Cafeteria     College Cafeteria
#
#                                      address        lat        lng  \
# 0  The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                            388 Spadina Ave  43.655454 -79.399163
# 2                                        NaN  43.655657 -79.389443
# 3                                        NaN  43.654179 -79.392555
# 4                             100 McCaul St.  43.652780 -79.391762
#
#                                       labeledLatLngs  distance  cc     city  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...       372  CA  Toronto
# 1  [{'label': 'display', 'lat': 43.65545427446646...       977  CA  Toronto
# 2  [{'label': 'display', 'lat': 43.655657, 'lng':...       260  CA  Toronto
# 3  [{'label': 'display', 'lat': 43.65417861938476...       431  CA      NaN
# 4  [{'label': 'display', 'lat': 43.65278016892648...       389  CA  Toronto
#
#   state country                                   formattedAddress  \
# 0    ON  Canada  [The Hospital for Sick Children (SickKids), To...
# 1    ON  Canada  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2    ON  Canada                               [Toronto ON, Canada]
# 3   NaN  Canada                                           [Canada]
# 4    ON  Canada  [100 McCaul St. (Second Floor), Toronto ON, Ca...
#
#     crossStreet postalCode                        id
# 0           NaN        NaN  4f9165bde4b04fef0087e4e2
# 1  at Nassau St    M5T 2G5  528e99a211d262edc3708a6f
# 2           NaN        NaN  53bd6dfe498e6c1d3bc9333e
# 3           NaN        NaN  556f826b498e07f469e6bf1f
# 4  Second Floor        NaN  4ec2b68a8231a83de8c45191

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2  Industrial Alliance Cafeteria             Cafeteria
# 3                Dears Cafeteria          Dessert Shop
# 4                 OCAD Cafeteria     College Cafeteria
#
#                                      address        lat        lng state  \
# 0  The Hospital for Sick Children (SickKids)  43.657209 -79.386063    ON
# 1                            388 Spadina Ave  43.655454 -79.399163    ON
# 2                                        NaN  43.655657 -79.389443    ON
# 3                                        NaN  43.654179 -79.392555   NaN
# 4                             100 McCaul St.  43.652780 -79.391762    ON
#
#   postalCode
# 0        NaN
# 1    M5T 2G5
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name         categories  \
# 1                       Stay Cafeteria 慢走   Asian Restaurant
# 7           De La Salle College Cafeteria  College Cafeteria
# 20                                The Hub  College Cafeteria
# 22                             Marketeria         Restaurant
# 25                          Innis College     Student Center
# 28  6th Floor Cafeteria 12 Concorde Place               Café
#
#                address        lat        lng state postalCode
# 1      388 Spadina Ave  43.655454 -79.399163    ON    M5T 2G5
# 7   131 Farnham Avenue  43.683003 -79.397815    ON    M4V 1H7
# 20    350 Victoria St.  43.658585 -79.380622    ON    M5B 2K3
# 22         30 Bond St.  43.653585 -79.378843    ON    M5B 1W8
# 25        2 Sussex Ave  43.665556 -79.399298    ON    M5S 1J5
# 28   12 Concorde Place  43.721861 -79.329339    ON    m3c 3k7

# %% [markdown]
# # Create DataFrame Shopping

# %%
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=G4G3BSMIJBOKSRFTLMKCCHCOYYAA5B4WMD1AHJPG0YN5RJ5P&client_secret=DSQT5Q4DQVFK04CDBSMY2ALHS5W50FZFVIYTQAZVLXWXKTCR&ll=43.653963,-79.387207&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
sresults = requests.get(url).json()
venues = sresults['response']['venues']
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
# <ipython-input-29-fc82f912e8a4>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   Shopping_dataframe = json_normalize(venues)
#                          id                                        name  \
# 0  4ad4c062f964a520fcf720e3                Dragon City Shopping Mall 龍城
# 1  4ad77a12f964a520260b21e3                     CF Toronto Eaton Centre
# 2  4b9e86dff964a520e6eb36e3                TD Centre Shopping Concourse
# 3  5840cafe06f1a34af80cc609  Saks Fifth Avenue Club - Personal Shopping
# 4  4b83d653f964a520d91231e3             Yellow Pages - RedFlagDeals.com
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1584887056    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1584887056    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1584887056    False
# 3  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...  v-1584887056    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1584887056    False
#
#      location.address location.crossStreet  location.lat  location.lng  \
# 0     280 Spadina Ave       at Dundas St W     43.652774    -79.398222
# 1        220 Yonge St  btwn Queen & Dundas     43.654540    -79.380677
# 2  66 Wellington St W    btw York & Bay St     43.647184    -79.380932
# 3    176 Yonge Street    Queen Street West     43.651810    -79.379192
# 4   461 King St. West                  NaN     43.647958    -79.396006
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...                897
# 1                                                NaN                529
# 2  [{'label': 'display', 'lat': 43.64718424611984...                908
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...                688
# 4  [{'label': 'display', 'lat': 43.64795765580337...                974
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5T 3A5          CA       Toronto             ON
# 1             M5B 2H1          CA       Toronto             ON
# 2             M5K 1A1          CA       Toronto             ON
# 3             M5C 2L7          CA       Toronto             ON
# 4             M5V 1K4          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1           Canada  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2           Canada  [66 Wellington St W (btw York & Bay St), Toron...
# 3           Canada  [176 Yonge Street (Queen Street West), Toronto...
# 4           Canada    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#            location.neighborhood
# 0                            NaN
# 1  Downtown Toronto, Toronto, ON
# 2                            NaN
# 3                            NaN
# 4                            NaN

# %%
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]
clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address          crossStreet        lat        lng  \
# 0     280 Spadina Ave       at Dundas St W  43.652774 -79.398222
# 1        220 Yonge St  btwn Queen & Dundas  43.654540 -79.380677
# 2  66 Wellington St W    btw York & Bay St  43.647184 -79.380932
# 3    176 Yonge Street    Queen Street West  43.651810 -79.379192
# 4   461 King St. West                  NaN  43.647958 -79.396006
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...       897    M5T 3A5  CA
# 1                                                NaN       529    M5B 2H1  CA
# 2  [{'label': 'display', 'lat': 43.64718424611984...       908    M5K 1A1  CA
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...       688    M5C 2L7  CA
# 4  [{'label': 'display', 'lat': 43.64795765580337...       974    M5V 1K4  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  Toronto    ON  Canada  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  Toronto    ON  Canada  [66 Wellington St W (btw York & Bay St), Toron...
# 3  Toronto    ON  Canada  [176 Yonge Street (Queen Street West), Toronto...
# 4  Toronto    ON  Canada    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                     neighborhood                        id
# 0                            NaN  4ad4c062f964a520fcf720e3
# 1  Downtown Toronto, Toronto, ON  4ad77a12f964a520260b21e3
# 2                            NaN  4b9e86dff964a520e6eb36e3
# 3                            NaN  5840cafe06f1a34af80cc609
# 4                            NaN  4b83d653f964a520d91231e3

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address        lat        lng postalCode state
# 0     280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 1        220 Yonge St  43.654540 -79.380677    M5B 2H1    ON
# 2  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 3    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 4   461 King St. West  43.647958 -79.396006    M5V 1K4    ON

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  Dragon City Shopping Mall 龍城  Shopping Mall     280 Spadina Ave  43.652774
# 1       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654540
# 2  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
#
#          lng postalCode state
# 0 -79.398222    M5T 3A5    ON
# 1 -79.380677    M5B 2H1    ON
# 2 -79.380932    M5K 1A1    ON

# %% [markdown]
# # map to visualize hotels, shopping stores and Cafeteria and how they cluster together¶

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df.head()
# Out:
#                             name         categories                address  \
# 0  Sheraton Centre Toronto Hotel              Hotel  123 Queen Street West
# 1                 Grand Ballroom        Event Space        123 Queen St. W
# 2              Stay Cafeteria 慢走   Asian Restaurant        388 Spadina Ave
# 3  De La Salle College Cafeteria  College Cafeteria     131 Farnham Avenue
# 4                        The Hub  College Cafeteria       350 Victoria St.
#
#          lat        lng postalCode state
# 0  43.650594 -79.384530    M5H 2M9    ON
# 1  43.651217 -79.383771    M5H 2M9    ON
# 2  43.655454 -79.399163    M5T 2G5    ON
# 3  43.683003 -79.397815    M4V 1H7    ON
# 4  43.658585 -79.380622    M5B 2K3    ON

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # map to visualize Park, Restaurant and Cafeteria and how they cluster together

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df.head()
# Out:
#                      name categories                       address        lat  \
# 0            Queen's Park       Park               University Ave.  43.663946
# 1    Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.  43.653610
# 2      Canoe Landing Park       Park             50 Fort York Blvd  43.638762
# 3     Riverdale Park West       Park               500 Gerrard St.  43.666048
# 4  Trinity Bellwoods Park       Park            1053 Dundas St. W.  43.647072
#
#          lng postalCode state
# 0 -79.392180    M5R 2E8    ON
# 1 -79.402199    M5T 2N4    ON
# 2 -79.397067    M5V 3Z1    ON
# 3 -79.360941    M5A 2H3    ON
# 4 -79.413756    M5H 2N2    ON

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
